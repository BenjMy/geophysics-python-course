# %% [markdown]
# # Introduction to resipy
#
# ## Overview
# resipy is a Python wrapper for R2/R3 electrical resistivity inversion codes.
#
# ## Learning Objectives
# - Understand electrical resistivity method
# - Create a resipy project
# - Import and visualize data
# - Run basic inversions

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from resipy import Project

# Create a new project
k = Project(typ='R2')
print("resipy project created successfully!")
# Out:
# API path =  /home/z0272571a@campus.csic.es/micromamba/envs/geophysics-course/lib/python3.10/site-packages/resipy
# ResIPy version =  3.6.6
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.
#
# This version of ResIPy requires wine to run R2.exe, please consider installing
# 'wine is not an emulator' package @ https://www.winehq.org/. On linux wine can be found on
# most reprositories (ubuntu/debian users can use "sudo apt install wine-stable"). Wine acts as
# a compatiblity layer between unix like OS systems (ie macOS and linux) and windows programs.
#
# Working directory is: /home/z0272571a@campus.csic.es/micromamba/envs/geophysics-course/lib/python3.10/site-packages/resipy
# Project created!
# resipy project created successfully!
# /bin/sh: 1: wine: not found
# /home/z0272571a@campus.csic.es/micromamba/envs/geophysics-course/lib/python3.10/site-packages/resipy/Project.py:262: Warning: Wine is not installed!
# ...
