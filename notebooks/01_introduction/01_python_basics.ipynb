# %% [markdown]
# # Introduction to Python Basics
#
# Welcome to the Geophysics Python Course!
#
# ## Learning Objectives
# - Understand Python syntax
# - Work with variables and data types
# - Use basic control structures
# - Introduction to functions

# %%
# Your first Python code
print("Hello, Geophysics!")

# %% [markdown]
# ## Variables and Data Types

# %%
# Numbers
resistivity = 100.5  # Ohm-m
num_electrodes = 48

# Strings
survey_type = "Wenner array"

# Lists
measurements = [12.5, 15.3, 18.7, 21.2]

print(f"Survey type: {survey_type}")
print(f"Number of electrodes: {num_electrodes}")
